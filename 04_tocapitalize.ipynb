# %%
import json

# Original JSON object
original_json = {
    "Activation": [
        "social media marketing",
        "campaign planning and execution",
        "content creation and management",
        "brand management",
        "event planning and management",
        "marketing analysis and optimization"
    ],
    "Brand": [
        "brand management",
        "marketing strategy",
        "advertising",
        "consumer insights",
        "market research",
        "product management"
    ]
,
    "Campaign": [
        "campaign planning and execution",
        "marketing strategy",
        "advertising",
        "promotion management",
        "budget management",
        "project management"
    ],
    "Creative Designer": [
        "graphic design",
        "visual communication",
        "branding",
        "marketing strategy",
        "advertising",
        "promotion management"
    ],
    "Head of Marketing": [
        "marketing strategy",
        "brand management",
        "advertising",
        "consumer insights",
        "market research",
        "team management"
    ],
    "Partnership": [
        "partnership management",
        "marketing strategy",
        "advertising",
        "promotion management",
        "budget management",
        "project management"
    ],
    "Performance": [
        "digital marketing",
        "marketing strategy",
        "advertising",
        "promotion management",
        "budget management",
        "project management"
    ]
}

# Capitalize each value in the lists
capitalized_json = {: [word.capitalize() for word in values] for key, values in original_json.items()}

# Print the capitalized JSON object
print(json.dumps(capitalized_json, indent=4))
# Out:
# {
#     "Activation": [
#         "Social media marketing",
#         "Campaign planning and execution",
#         "Content creation and management",
#         "Brand management",
#         "Event planning and management",
#         "Marketing analysis and optimization"
#     ],
#     "Brand": [
#         "Brand management",
#         "Marketing strategy",
#         "Advertising",
#         "Consumer insights",
#         "Market research",
#         "Product management"
#     ],
#     "Campaign": [
#         "Campaign planning and execution",
#         "Marketing strategy",
#         "Advertising",
#         "Promotion management",
#         "Budget management",
#         "Project management"
#     ],
#     "Creative Designer": [
#         "Graphic design",
#         "Visual communication",
#         "Branding",
#         "Marketing strategy",
#         "Advertising",
#         "Promotion management"
#     ],
#     "Head of Marketing": [
#         "Marketing strategy",
# ...
